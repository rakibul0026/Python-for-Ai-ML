# %%
#1st Example

# %%
marks=[10,20,30,40,50]
pass_marks=list(filter(lambda x: x>=30,marks))
print(pass_marks)
# Out:
# [30, 40, 50]

# %%
#2nd Example

# %%
import pandas as pd
df=pd.DataFrame({'price':[1,2,3,4],'item':['pen','book','bag','pencil']})
expensive_items=df[df['price']>=3]
print(expensive_items)
# Out:
#    price    item
# 2      3     bag
# 3      4  pencil
