# %% [markdown]
# JSON in Python

# %%
import json
x={"Name":"John", "Age":30, "City":"New York"}
print(x)
# Out:
# {'Name': 'John', 'Age': 30, 'City': 'New York'}

# %%
import json
x_string = '{"Name":"John", "Age":30, "City":"New York"}'

y = json.loads(x_string)
print(y["Age"])
# Out:
# 30
